# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-dark')

# %%
df = pd.read_excel('/Users/matiasluraschi/Library/Mobile Documents/com~apple~CloudDocs/Varios/UNIMI/Advanced Macroeconomic Massaro/Macro Project/macro dati final.xlsx', 'Sheet1',index_col='DATE')
df.head()
# Out:
#          TC NOMINAL  MB MONTHLY CHANGE  INFLATION INTERANNUAL CHANGE  \
# DATE
# 2015-12   12.238000              0.112                         0.269
# 2016-01   13.894500             -0.031                         0.221
# 2016-02   15.027368             -0.065                         0.242
# 2016-03   15.183810              0.042                         0.262
# 2016-04   14.658095             -0.008                         0.290
#
#          INFLATION MONTHLY CHANGE  CORE INFLATION MONTHLY CHANGE  \
# DATE
# 2015-12                     0.039                          0.045
# 2016-01                     0.041                          0.041
# 2016-02                     0.040                          0.030
# 2016-03                     0.033                          0.035
# 2016-04                     0.065                          0.028
#
#          NOMINAL TC MONTHLY CHANGE  LAGGED MB INTERANNUAL CHANGE  \
# DATE
# 2015-12                   0.153000                      0.405097
# ...

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

# %%
# Inflation Graph. One for whole thing. Since 1989 has hiperinflation (3000%), made two subgraphs.
# Second subgraph is limited until 70% inflation a year to show more precisely the variation since 2002. 

#datos
df_tc = pd.read_excel('/Users/matiasluraschi/Library/Mobile Documents/com~apple~CloudDocs/Varios/UNIMI/Advanced Macroeconomic Massaro/Macro Project/macro dati final.xlsx', 'Sheet2')
x = df_tc['Inflation Rate']
y = df_tc['Year']
plt.rcParams['axes.grid'] = True
fig, axs = plt.subplots(2, figsize=(10,7),dpi=150)
fig.suptitle('Annual inflation rate', weight='bold', fontsize=12)
#primer grafico
axs[0].plot(y, x, color='red',marker='o', markersize=2, label='Annual inflation rate')

#segundo grafico
axs[1].plot(y, x, color='red',marker='o', markersize=2, label='Annual inflation rate')
axs[1].set_ylim((-3,70))
plt.xlabel('Date', weight='bold',fontsize=12)
axs[0].legend(loc='best')
axs[1].legend(loc='best')
plt.savefig('inflatotal2.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/w7/37qc0_js2sb8xtxk5n7ltq5r0000gn/T/ipykernel_40097/2886213292.py in <module>
#       3
#       4 #datos
# ----> 5 df_tc = pd.read_excel('/Users/matiasluraschi/Library/Mobile Documents/com~apple~CloudDocs/Varios/UNIMI/Advanced Macroeconomic Massaro/Macro Project/macro dati final.xlsx', 'Sheet2')
#       6 x = df_tc['Inflation Rate']
#       7 y = df_tc['Year']
#
# /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#Exchange Rate Graph. 
plt.figure(figsize=(8,4),dpi=150)
plt.plot(df['TC NOMINAL'], color='red', label='Nominal Exchange Rate', marker='^', markersize=3.5)
plt.grid()
plt.xlabel('Date', weight='bold',fontsize=12)
plt.ylabel('Argentine Pesos per Dolar', weight='bold', fontsize=12)
plt.title('Exchange Rate', weight='bold', fontsize=15)
plt.xticks(rotation=45, fontsize=6.5, weight='bold')
plt.axvline(x='2017-12',color='black', ls='--')
plt.axvline(x='2018-06',color='black', ls='--')
plt.axvline(x='2018-10',color='black', ls='--')
plt.axvline(x='2019-07',color='black', ls='--')
plt.legend(loc='best')
plt.annotate('Change of Inflation Targetting Regime',xy=('2017-11',35), color='black', rotation=90, fontsize=7)
plt.annotate('First IMF Agreement',xy=('2018-05',49), color='black', rotation=90, fontsize=7)
plt.annotate('Second IMF Agreement',xy=('2018-09',46.3), color='black', rotation=90, fontsize=7)
plt.annotate('2019 Presidential Elections',xy=('2019-06',11), color='black', rotation=90, fontsize=7)
##plt.show()
#plt.savefig('tcnominal.pdf', bbox_inches='tight')
# Out:
# Text(2019-06, 11, '2019 Presidential Elections')

# %%
df1 = pd.read_excel('/Users/matiasluraschi/Library/Mobile Documents/com~apple~CloudDocs/Varios/UNIMI/Advanced Macroeconomic Massaro/Macro Project/macro dati final.xlsx', 'BM FINAL',index_col='DATE')

# %%
#Graphs of Month to Month variation on REAL Monetary Base, Exchange Rate and Inflation. 
plt.rcParams['axes.grid'] = True
fig, axs = plt.subplots(3, figsize=(8,8),dpi=150)
fig.suptitle('Month-to-month variation', weight='bold', fontsize=12)
plt.xlabel('Date', weight='bold',fontsize=12)
#primer grafico
axs[0].plot(df1['VAR BM REAL'], color='blue',marker='o', markersize=3,label='Variation Real MB')
axs[0].axhline(y=-0.005602871903962418,color='black', ls='-.',label='Average variation Real MB 2017-2019')
#SEGUNDO GRAFICO
axs[1].plot(df1['VAR TC NOMINAL'], color='orange', marker='x', markersize=3,label='Variation Exchange Rate')
axs[1].axhline(y=0.04076587862556902,color='black', ls='-.',label='Average variation Exchange Rate 2017-2019')
##tercer grafico
axs[2].plot(df1['Inflation'], color='red', marker='^', markersize=3,label='Variation Inflation')
axs[2].axhline(y=0.029000000000000005,color='black', ls='-.',label='Average variation Inflation 2017-2019')
plt.legend(loc='best')
axs[0].legend(loc='best')
axs[1].legend(loc='best')
#plt.savefig('variaciones.pdf', bbox_inches='tight')

# %%
df_mone = pd.read_excel('/Users/matiasluraschi/Library/Mobile Documents/com~apple~CloudDocs/Varios/UNIMI/Advanced Macroeconomic Massaro/Macro Project/macro dati final.xlsx', 'BM FINAL',index_col='DATE')
df_mone.head()
# Out:
#                    BM VER  Variacion BM VER               BM   \
# DATE
# 2016-12  7878950516120509          0.000000  7878950516120510
# 2017-01  8058935777759905          0.022844  8154861290322580
# 2017-02  8052916227454834         -0.000747  8270361071428570
# 2017-03  7530860908569408         -0.064828  7906025806451610
# 2017-04  7342484720554134         -0.025014  7892576333333330
#
#          ipc_bienes_nacional  BASE DIC 2016   BMI/IPC            BM/IPC  \
# DATE
# 2016-12             100.0000     100.000000  1.000000  7878950516120509
# 2017-01             101.1903     103.501872  1.022844  8058935777759905
# 2017-02             102.7002     104.967801  1.022080  8052916227454834
# 2017-03             104.9817     100.343641  0.955820  7530860908569408
# 2017-04             107.4919     100.172939  0.931912  7342484720554134
#
#          VAR BM REAL  Inflation  INFLA COMP     MB/INFLA COMP  VAR MB RR  \
# DATE
# ...

# %%
# REAL MONETARY BASE AND NOMINAL MONETARY BASE
plt.figure(figsize=(8,4),dpi=150)
plt.plot(df_mone['BM'], color='blue', label='Nominal Monetary Base', marker='o', markersize=3.5, alpha=0.6)
plt.plot(df_mone['BM VER'], color='orange', label='Real Monetary Base', marker='^', markersize=3.5)
plt.grid()
plt.xlabel('Date', weight='bold',fontsize=12)
plt.ylabel('Monetary Base', weight='bold', fontsize=12)
plt.title('Real and Nominal Monetary Base', weight='bold', fontsize=15)
plt.xticks(rotation=45, fontsize=6.5, weight='bold')
plt.axvline(x='2018-05',color='black', ls='--')
plt.axvline(x='2018-10',color='black', ls='--')
plt.axvline(x='2019-07',color='black', ls='--')
plt.annotate('First IMF Agreement',xy=('2018-04',13782888671617920.00), color='black', rotation=90, fontsize=7)
plt.annotate('Second IMF Agreement',xy=('2018-09',13182888671617920.00), color='black', rotation=90, fontsize=7)
plt.annotate('2019 Presidential Elections',xy=('2019-06',12662888671617920.00), color='black', rotation=90, fontsize=7)
plt.legend(loc='best')
plt.show()
#plt.savefig('basemonetariafinal1.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BM'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Evolution of Price Index 
plt.figure(figsize=(8,4),dpi=150)
plt.plot(df_mone['ipc_bienes_nacional'], color='red', label='Consumer Price Index', marker='o', markersize=3.5, alpha=0.4)
ax.grid(True)
plt.xlabel('Date', weight='bold',fontsize=12)
plt.ylabel('Consumer Prince Index', weight='bold', fontsize=12)
plt.title('Consumer Price Index', weight='bold', fontsize=15)
plt.legend(loc='best')
plt.xticks(rotation=45, fontsize=6.5, weight='bold')
plt.axvline(x='2018-05',color='black', ls='--')
plt.axvline(x='2018-10',color='black', ls='--')
plt.axvline(x='2019-07',color='black', ls='--')
plt.annotate('First IMF Agreement',xy=('2018-04',233), color='black', rotation=90, fontsize=7)
plt.annotate('Second IMF Agreement',xy=('2018-09',223), color='black', rotation=90, fontsize=7)
plt.annotate('2019 Presidential Elections',xy=('2019-06',213), color='black', rotation=90, fontsize=7)
plt.legend(loc='best')
plt.show()
#plt.savefig('consumerpi.pdf', bbox_inches='tight')

# %%
dff5 = pd.read_excel('/Users/matiasluraschi/Library/Mobile Documents/com~apple~CloudDocs/Varios/UNIMI/Advanced Macroeconomic Massaro/Macro Project/macro dati final.xlsx', 'FINAL 4',index_col='DATE')
coefpearson4 = dff5.corr(method ='pearson')
coefpearson4
# Out:
#                       Monthly Inflation  ER Variation  Real MB Variation  \
# Monthly Inflation              1.000000      0.366190          -0.231522
# ER Variation                   0.366190      1.000000          -0.126045
# Real MB Variation             -0.231522     -0.126045           1.000000
# Nominal MB Variation           0.079722      0.020075           0.199641
#
#                       Nominal MB Variation
# Monthly Inflation                 0.079722
# ER Variation                      0.020075
# Real MB Variation                 0.199641
# Nominal MB Variation              1.000000

# %%
df_corr = dff5.corr()
plt.figure(figsize=(8.3,7),dpi=150)
ax = sns.heatmap(df_corr, annot=True) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_ylim(sorted(ax.get_xlim(), reverse=True))
#plt.savefig('coeficiente2.pdf')
# Out:
# (4.0, 0.0)
